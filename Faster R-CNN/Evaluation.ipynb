# %%
# %matplotlib notebook
#Ziyan Zhu
import numpy as np 
from matplotlib import pyplot as plt

# %%
AP_VGG = [0, 0.4227096907815568, 0.3536978647313009, 0.07921172226300235, 0.1531742220205019, 0.4825914345830311, 0.3804048612193307, 0.5802064907327946, 0.1833829061532683, 0.16407711337842257, 0.10977133689101118, 0.5285145106122815, 0.37588831583405313, 0.467525072910589, 0.46778266454586054, 0.09998531580805553, 0.34586233828715424, 0.13927829746084408, 0.35213718021062473, 0.3549214615788696]

AP_Resnet = [0, 0.8194075994299554, 0.7956268011935239, 0.6494860175547076, 0.658286149588392, 0.8515088265260637, 0.8289890629538603, 
             0.9201345387392836, 0.5775837698342481, 0.8021528601212848, 0.6351181345492056, 0.8270728024312672, 0.843054867329424, 
             0.8612131887981553, 0.8650857725117728, 0.5683088195812955, 0.8075317683271428, 0.686984360008667, 0.8497802341980747, 0.7620357133920168]

AP_Desnet = [0, 0.42012839299687804, 0.34550664255250896, 0.13764769804628063, 0.17969934333173995, 0.5894136997594948, 0.35056790903565815, 0.6147392364063562, 0.21349812874169619, 0.26820696234643526, 0.2294800491900914, 0.6051704823063062, 0.45421635901240687, 0.556384323855107, 0.5310420453702874, 0.15089600499191821, 0.2724307113513159, 0.32557382684000225, 0.5668113826491964, 0.3494592461612025]

AP_MobileNet = [0, 0.5090008256805434, 0.3277141504547701, 0.1400813530602902, 0.16755692305029166, 0.627509249896987, 0.45194141713025593, 0.5974411146845271, 0.1987518304297501, 0.3857648384878389, 0.2938115732931955, 0.5662459596913779, 0.5306230517534296, 0.5870686601140912, 0.5046171802074361, 0.1420221564547731, 0.39991755334180074, 0.22966115161524497, 0.553632067762708, 0.39549970597946715]

AP_YOLO = [0.6747607516048957, 0.4744994313337705, 0.4733009767154323, 0.25147645720217293, 0.24069967473739423, 0.6642947252801901, 0.4635521258144459, 0.6540503534526785, 0.22772502774604295, 0.300245176672717, 0.24434229872579427, 0.5695622960541485, 0.5319232140746593, 0.5386577975475344, 0.4600143312590751, 0.21324666479391413, 0.46775919158724555, 0.30716554808288676, 0.6533549968849159, 0.474202836425731]

# %%
x = np.arange(20)   
y_1 = AP_Resnet
y_2 = AP_VGG
y_3 = AP_Desnet
y_4 = AP_MobileNet
y_5 = AP_YOLO

width = 0.15
fig,ax = plt.subplots(figsize=(10, 5))
plt.ylim(0, 1)
ax.bar(x,y_1,width,alpha = 1, label = 'Faster R-CNN ResNet-50')
ax.bar(x+width,y_2,width,alpha = 1,color= 'red', label = 'Faster R-CNN VGG-16')
ax.bar(x+2*width,y_3,width,alpha = 1,color= 'yellow', label = 'Faster R-CNN DenseNet-121')
ax.bar(x+3*width,y_4,width,alpha = 1,color= 'orange', label = 'Faster R-CNN Mobile_v2')
ax.bar(x+4*width,y_5,width,alpha = 1,color= 'pink', label = 'YOLO ResNet-50')
ax.set_xticks(x +2*width)
ax.set_xticklabels(x)
ax.set(xlabel = 'class', ylabel = 'Average Precision' )
ax.legend(prop={'size': 8})
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
np.mean(y_1)
# Out:
# 0.7304680643534172

# %%
np.mean(y_2)
# Out:
# 0.3020561400001277

# %%
np.mean(y_3)
# Out:
# 0.3580436222472441

# %%
np.mean(y_4)
# Out:
# 0.3804430381544389
